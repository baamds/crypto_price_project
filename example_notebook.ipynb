# %%
from features import compute_features
import pandas as pd

# Exempel:
df = pd.read_csv('data/btc_usd.csv')
features = compute_features(df)
features.head()

features.median()
# Out:
# timestamp         2021-07-11 12:00:00
# close                    22486.539062
# close_btc-usd            22486.539062
# high_btc-usd             22991.483398
# low_btc-usd              21960.554688
# open_btc-usd             22466.679688
# volume_btc-usd          24223676478.0
# ret_1                        0.000791
# ret_7                        0.005113
# vol_7                        0.026987
# vol_21                       0.029757
# mom_7                        0.005113
# sma_7                    22400.603097
# sma_21                   22485.289249
# rsi_14                      51.987048
# target_close_1           22530.114258
# target_ret_1                 0.000791
# dtype: object

# %% [markdown]
# # Jupyter-notebook: Crypto Price Prediction
#
# Denna notebook visar hur du kan ladda data, extrahera features och köra en snabbträning. Kör skripten i terminal om du föredrar det.
